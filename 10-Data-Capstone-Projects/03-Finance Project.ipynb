# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
from pandas_datareader import data as pdr
from pandas_datareader import wb
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import yfinance as yf
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
# 1. Define your timeframe
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

#2. Download directly via yfinance
BAC = yf.download("BAC", start=start, end=end)
# 3. Check that it worked
print(BAC.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            BAC        BAC        BAC        BAC       BAC
# Date
# 2006-01-03  30.176386  30.240481  29.580293  30.073830  16296700
# 2006-01-04  29.855898  30.278931  29.772572  30.125100  17757900
# 2006-01-05  29.894360  30.016143  29.689253  29.855904  14970700
# 2006-01-06  29.849501  30.067427  29.708489  29.996921  12599800
# 2006-01-09  29.868725  30.105882  29.714896  29.945642  15619400

# %%
BAC
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker            BAC        BAC        BAC        BAC       BAC
# Date
# 2006-01-03  30.176386  30.240481  29.580293  30.073830  16296700
# 2006-01-04  29.855898  30.278931  29.772572  30.125100  17757900
# 2006-01-05  29.894360  30.016143  29.689253  29.855904  14970700
# 2006-01-06  29.849501  30.067427  29.708489  29.996921  12599800
# 2006-01-09  29.868725  30.105882  29.714896  29.945642  15619400
# ...               ...        ...        ...        ...       ...
# 2015-12-24  13.652233  13.739189  13.612706  13.691758  29369400
# 2015-12-28  13.541554  13.620606  13.422977  13.612701  41777500
# 2015-12-29  13.660135  13.715471  13.565273  13.636419  45670400
# 2015-12-30  13.478314  13.628513  13.470411  13.596893  35066400
# 2015-12-31  13.304402  13.494126  13.304402  13.446696  47153000
#
# [2517 rows x 5 columns]

# %%
BAC.head()
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker            BAC        BAC        BAC        BAC       BAC
# Date
# 2006-01-03  30.176386  30.240481  29.580293  30.073830  16296700
# 2006-01-04  29.855898  30.278931  29.772572  30.125100  17757900
# 2006-01-05  29.894360  30.016143  29.689253  29.855904  14970700
# 2006-01-06  29.849501  30.067427  29.708489  29.996921  12599800
# 2006-01-09  29.868725  30.105882  29.714896  29.945642  15619400

# %%
#2. Download directly via yfinance
JPM = yf.download("JPM", start=start, end=end)
# 3. Check that it worked
print(JPM.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            JPM        JPM        JPM        JPM       JPM
# Date
# 2006-01-03  23.527687  23.627208  23.006671  23.316941  12838600
# 2006-01-04  23.391895  23.698907  23.273814  23.486360  13491500
# 2006-01-05  23.462746  23.504074  23.321047  23.385992   8109400
# 2006-01-06  23.628065  23.757955  23.350573  23.569023   7966900
# 2006-01-09  24.011826  24.041348  23.545406  23.545406  16575200

# %%
#2. Download directly via yfinance
MS = yf.download("MS", start=start, end=end)
# 3. Check that it worked
print(MS.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume
# Ticker             MS         MS         MS         MS       MS
# Date
# 2006-01-03  31.011330  31.107060  30.176348  30.405035  5377000
# 2006-01-04  31.032612  31.527219  31.032612  31.218756  7977800
# 2006-01-05  31.117697  31.160245  30.857098  31.138971  5778000
# 2006-01-06  31.149622  31.298535  30.873067  31.255990  6889800
# 2006-01-09  31.479355  31.532540  31.176209  31.181528  4144500

# %%
#2. Download directly via yfinance
GS = yf.download("GS", start=start, end=end)
# 3. Check that it worked
print(GS.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume
# Ticker             GS         GS         GS         GS       GS
# Date
# 2006-01-03  92.496353  92.905476  89.166002  90.938838  6188700
# 2006-01-04  91.218742  92.525051  90.709141  91.405359  4861600
# 2006-01-05  91.182922  91.383891  90.156540  90.436462  3717400
# 2006-01-06  92.474815  92.769095  91.362307  91.362307  4319600
# 2006-01-09  93.587341  93.752421  91.871921  92.230795  4723500

# %%
#2. Download directly via yfinance
C = yf.download("C", start=start, end=end)
# 3. Check that it worked
print(C.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker               C           C           C           C        C
# Date
# 2006-01-03  312.726746  313.297758  305.240091  310.886807  1537600
# 2006-01-04  306.953186  311.521327  306.762855  309.998620  1870960
# 2006-01-05  308.475952  309.491078  307.080126  307.333907  1143160
# 2006-01-06  308.475952  310.252441  305.811200  310.125541  1370210
# 2006-01-09  307.016449  309.237068  306.445437  308.348824  1680740

# %%
#2. Download directly via yfinance
WFC = yf.download("WFC", start=start, end=end)
# 3. Check that it worked
print(WFC.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            WFC        WFC        WFC        WFC       WFC
# Date
# 2006-01-03  18.170349  18.213070  17.768779  17.999469  11016400
# 2006-01-04  17.959591  18.124775  17.865606  18.113383  10870000
# 2006-01-05  17.939661  17.973837  17.834284  17.942509  10158000
# 2006-01-06  18.045029  18.099141  17.876996  17.988068   8403800
# 2006-01-09  18.042179  18.127620  17.973827  18.042179   5619600

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
# Download all of them into a single, clean Multi-Index DataFrame
bank_stocks = yf.download(tickers, start=start, end=end)
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
# Preview your new multi-bank dataset
bank_stocks.head()
# Out:
# Price           Close                                                          \
# Ticker            BAC           C         GS        JPM         MS        WFC
# Date
# 2006-01-03  30.176386  312.726746  92.496353  23.527687  31.011330  18.170349
# 2006-01-04  29.855898  306.953186  91.218742  23.391895  31.032612  17.959591
# 2006-01-05  29.894360  308.475952  91.182922  23.462746  31.117697  17.939661
# 2006-01-06  29.849501  308.475952  92.474815  23.628065  31.149622  18.045029
# 2006-01-09  29.868725  307.016449  93.587341  24.011826  31.479355  18.042179
#
# Price            High                                    ...       Open  \
# Ticker            BAC           C         GS        JPM  ...         GS
# Date                                                     ...
# 2006-01-03  30.240481  313.297758  92.905476  23.627208  ...  90.938838
# 2006-01-04  30.278931  311.521327  92.525051  23.698907  ...  91.405359
# ...

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bankStocks = pd.concat([BAC,C,GS,JPM,MS,WFC], axis=1,keys=tickers)

# %%
bankStocks.head()
# Out:
#                   BAC                                                      C  \
# Price           Close       High        Low       Open    Volume       Close
# Ticker            BAC        BAC        BAC        BAC       BAC           C
# Date
# 2006-01-03  30.176386  30.240481  29.580293  30.073830  16296700  312.726746
# 2006-01-04  29.855898  30.278931  29.772572  30.125100  17757900  306.953186
# 2006-01-05  29.894360  30.016143  29.689253  29.855904  14970700  308.475952
# 2006-01-06  29.849501  30.067427  29.708489  29.996921  12599800  308.475952
# 2006-01-09  29.868725  30.105882  29.714896  29.945642  15619400  307.016449
#
#                                                          ...         MS  \
# Price             High         Low        Open   Volume  ...      Close
# Ticker               C           C           C        C  ...         MS
# Date                                                     ...
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bankStocks.columns.names = [None, 'Price', 'Ticker']

# %%
bankStocks.columns.names
# Out:
# FrozenList([None, 'Price', 'Ticker'])

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker      Close                                               \
# Stock Info         BAC           C         GS        JPM         MS
# Date
# 2006-01-03   30.176386  312.726746  92.496353  23.527687  31.011330
# 2006-01-04   29.855898  306.953186  91.218742  23.391895  31.032612
# 2006-01-05   29.894360  308.475952  91.182922  23.462746  31.117697
# 2006-01-06   29.849501  308.475952  92.474815  23.628065  31.149622
# 2006-01-09   29.868725  307.016449  93.587341  24.011826  31.479355
#
# Bank Ticker                  High                                    ...  \
# Stock Info         WFC        BAC           C         GS        JPM  ...
# Date                                                                 ...
# 2006-01-03   18.170349  30.240481  313.297758  92.905476  23.627208  ...
# 2006-01-04   17.959591  30.278931  311.521327  92.525051  23.698907  ...
# 2006-01-05   17.939661  30.016143  309.491078  91.383891  23.504074  ...
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
for tick in tickers:
   print(tick,bankStocks[tick]['Close'].max())
# Out:
# BAC Ticker
# BAC    36.493515
# dtype: float64
# C Ticker
# C    372.837006
# dtype: float64
# GS Ticker
# GS    180.61499
# dtype: float64
# JPM Ticker
# JPM    52.345318
# dtype: float64
# MS Ticker
# MS    48.613708
# dtype: float64
# WFC Ticker
# WFC    42.835339
# dtype: float64

# %%
bankStocks.xs(key='Close', axis=1,level='Price').max()
# Out:
#      Ticker
# BAC  BAC        36.493515
# C    C         372.837006
# GS   GS        180.614990
# JPM  JPM        52.345318
# MS   MS         48.613708
# WFC  WFC        42.835339
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
for tick in tickers:
    returns[tick+' Return'] = bankStocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013813   -0.005772   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014168    0.007046   0.001026    0.005873
# 2006-01-09    0.000644 -0.004731   0.012031    0.016242   0.010585   -0.000158

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013813   -0.005772   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014168    0.007046   0.001026    0.005873
# 2006-01-09    0.000644 -0.004731   0.012031    0.016242   0.010585   -0.000158

# %%
returns.min()
# Out:
# BAC Return   -0.289694
# C Return     -0.390244
# GS Return    -0.189596
# JPM Return   -0.207274
# MS Return    -0.258929
# WFC Return   -0.238223
# dtype: float64

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std()
# Out:
# BAC Return    0.036659
# C Return      0.038672
# GS Return     0.025386
# JPM Return    0.027675
# MS Return     0.037717
# WFC Return    0.030195
# dtype: float64

# %%
returns.loc['2015-01-01' : '2015-12-31'].std()
# Out:
# BAC Return    0.016174
# C Return      0.015288
# GS Return     0.014043
# JPM Return    0.014006
# MS Return     0.016287
# WFC Return    0.012552
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.displot(returns.loc['2015-01-01' : '2015-12-31']['MS Return'],color='green', bins=50)

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.displot(returns.loc['2008-01-01' : '2008-12-31']['C Return'],color='red',bins=50)

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.0.0.min"</script>

# %%
import plotly.express as px
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import chart_studio.plotly as py

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
for tick in tickers:
    bankStocks[tick]['Close'].plot(label=tick,figsize=(12,4))
    plt.legend()

# %%
bankStocks.xs(key='Close', axis=1, level='Price').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# For Notebooks
init_notebook_mode(connected=True)
# For offline use
cf.go_offline()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.0.0.min"</script>
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.0.0.min"</script>

# %%
close_prices = bankStocks.xs(key='Close', axis=1, level='Price')
close_prices
# Out:
#                   BAC           C          GS        JPM         MS        WFC
# Ticker            BAC           C          GS        JPM         MS        WFC
# Date
# 2006-01-03  30.176386  312.726746   92.496353  23.527687  31.011330  18.170349
# 2006-01-04  29.855898  306.953186   91.218742  23.391895  31.032612  17.959591
# 2006-01-05  29.894360  308.475952   91.182922  23.462746  31.117697  17.939661
# 2006-01-06  29.849501  308.475952   92.474815  23.628065  31.149622  18.045029
# 2006-01-09  29.868725  307.016449   93.587341  24.011826  31.479355  18.042179
# ...               ...         ...         ...        ...        ...        ...
# 2015-12-24  13.652233   38.787506  146.561020  50.104927  24.072275  40.666603
# 2015-12-28  13.541554   38.544666  145.878311  49.939392  23.842520  40.562744
# 2015-12-29  13.660135   38.986195  147.412430  50.458523  24.124157  41.015236
# 2015-12-30  13.478314   38.485786  146.191544  50.097389  23.886990  40.718517
# ...

# %%
fig = bankStocks.xs(key='Close', axis=1, level='Price').droplevel(axis=1, level=0).plot(
    title="Bank Stock Closing Prices",
    labels={"value": "Price ($)", "index": "Date", "variable": "Ticker"}
)
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
pd.options.plotting.backend = "matplotlib"
plt.figure(figsize=(12,6))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day MA', color='orange')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE', color='blue')
plt.legend()
plt.show()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(bankStocks.xs(key='Close', axis=1, level='Price').corr(),annot=True)
# Out:
# <Axes: xlabel='None-Ticker', ylabel='None-Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(bankStocks.xs(key='Close', axis=1, level='Price').corr(),annot=True)

# %%
# Out:
# <div id="cfe3f8e3-825e-438f-9ede-9f7bd2e2ad65" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cfe3f8e3-825e-438f-9ede-9f7bd2e2ad65", [{"type": "heatmap", "x": ["BAC", "C", "GS", "JPM", "MS", "WFC"], "y": ["BAC", "C", "GS", "JPM", "MS", "WFC"], "colorscale": [[0.0, "rgb(165,0,38)"], [0.1, "rgb(215,48,39)"], [0.2, "rgb(244,109,67)"], [0.3, "rgb(253,174,97)"], [0.4, "rgb(254,224,144)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(224,243,248)"], [0.7, "rgb(171,217,233)"], [0.8, "rgb(116,173,209)"], [0.9, "rgb(69,117,180)"], [1.0, "rgb(49,54,149)"]], "z": [[1.0, 0.9715137697087325, 0.5509501372549771, 0.10389606365085878, 0.9442192943385206, 0.008566851425732356], [0.9715137697087325, 1.0, 0.4341706182992412, 0.003539648273630715, 0.9336049414173658, -0.06844121334375318], [0.5509501372549771, 0.43417061829
# ...

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
close_corr= bankStocks.xs(key='Close', axis=1, level='Price').corr()
close_corr
# Out:
#                  BAC         C        GS       JPM        MS       WFC
# Ticker           BAC         C        GS       JPM        MS       WFC
#     Ticker
# BAC BAC     1.000000  0.961371  0.477061 -0.063154  0.915898 -0.118169
# C   C       0.961371  1.000000  0.326658 -0.191992  0.867036 -0.225295
# GS  GS      0.477061  0.326658  1.000000  0.680386  0.721906  0.553583
# JPM JPM    -0.063154 -0.191992  0.680386  1.000000  0.188445  0.965022
# MS  MS      0.915898  0.867036  0.721906  0.188445  1.000000  0.107004
# WFC WFC    -0.118169 -0.225295  0.553583  0.965022  0.107004  1.000000

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
import plotly.express as px

fig = px.imshow(
    close_corr,
    text_auto='.2f',
    color_continuous_scale='RdBu_r',
)

fig.update_layout(
    title="Correlation Heatmap"
)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#close_corr.plot(kind='heatmap',colorscale='rdylbu')

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
BAC
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker            BAC        BAC        BAC        BAC       BAC
# Date
# 2006-01-03  30.176386  30.240481  29.580293  30.073830  16296700
# 2006-01-04  29.855898  30.278931  29.772572  30.125100  17757900
# 2006-01-05  29.894360  30.016143  29.689253  29.855904  14970700
# 2006-01-06  29.849501  30.067427  29.708489  29.996921  12599800
# 2006-01-09  29.868725  30.105882  29.714896  29.945642  15619400
# ...               ...        ...        ...        ...       ...
# 2015-12-24  13.652233  13.739189  13.612706  13.691758  29369400
# 2015-12-28  13.541554  13.620606  13.422977  13.612701  41777500
# 2015-12-29  13.660135  13.715471  13.565273  13.636419  45670400
# 2015-12-30  13.478314  13.628513  13.470411  13.596893  35066400
# 2015-12-31  13.304402  13.494126  13.304402  13.446696  47153000
#
# [2517 rows x 5 columns]

# %%
bac15 = BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01' : '2016-01-01']
bac15.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
##MS['Close'].loc['2015-01-01' : '2016-01-01'].ta_plot(study='sma',periods=[13,21,55])

# %%
import cufflinks
import plotly
import numpy
print("cufflinks:", cufflinks.__version__)
print("plotly:", plotly.__version__)
print("numpy:", numpy.__version__)
# Out:
# cufflinks: 0.17.3
# plotly: 7.0.0
# numpy: 2.2.6

# %%
## BAC['Close'].loc['2015-01-01' : '2016-01-01'].ta_plot(study='boll')

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
